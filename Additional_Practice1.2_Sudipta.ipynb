# %% [markdown]
# ## Please replace the astricks with the required logic in the following exercises

# %% [markdown]
# ### 1) Write a python program to print from 1 to 6 except 3 and 6
#
#        Expected Output:
#
#        1  2  4  5

# %%
# Iterate over range from 1 to 6 using for loop
for x in range(6):

#check if x is 3 or 6
    if(x == 0 or x == 3 or x ==6):
        continue
    else:
        print(x, end = " ")
# Out:
# 1 2 4 5

# %%
# Iterate over range from 1 to 6 using for loop
for x in range(1,6):

#check if x is 3 or 6
    if(x == 3 or x ==6):
        continue
    else:
        print(x, end = " ")
# Out:
# 1 2 4 5

# %% [markdown]
# ### 2) Write a Python program to construct the following pattern, using a nested for loop.
#
#         *
#         * *
#         * * *
#         * * * *
#         * * * * *
#         * * * *
#         * * *
#         * *
#         *

# %%
n=5
for i in range(n):
    for j in range(i):
        print ('*', end=" ")
    print('')

for i in range(n,0,-1):
    for j in range(i):
        print('*', end =" ")
    print('')
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
for i in range(1,6):
    print(i*'* ')

for j in range(4,0,-1):
    print(j*'* ')
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %% [markdown]
# ### 3) Write a python program to print the sum of the first 10 numbers (1 to 10) using while loop
#
#         Expected Output:
#         The sum of the first 10 integers:  55

# %%
# Initialize x to 1
x = 1

# Initialize s to 0
s = 0


# Iterate over x till 10
while (x <= 10):

# Add each x to s
    s = x + s

# Increment x by 1
    x = x + 1

#when x>10, print s
print("The sum of the first 10 integers: ",s)
# Out:
# The sum of the first 10 integers:  55

# %% [markdown]
# ### 4) We use break statement to terminate the while loop without completing all the iterations. The program control goes outside the while and the next print statement is executed. Q. Repeat the while using âbreakâ and print the sum of the first 10 integers
#
#         Expected Output:
#         The sum of the first 10 integers is: 55

# %%
# Initialize x to 1

x = 1

# Initialize s to 0

s = 0

# Infinite loop using while
while (True):
    
#check for x =11
     if (x==11):
          break    

# Add each x to s
     s = s + x

#Increment x by 1
     x = x + 1

#print sum s
print('The sum of first 10 numbers is:', s)
# Out:
# The sum of first 10 numbers is: 55

# %% [markdown]
# ### 5) Print the whether the number is positive or negative

# %%
#initialize any negative number or positive number
num = -3

#check if num>0
if (num > 0):

#print the number is positive
    print("positive number")

#use elif to check number is zero
elif (num == 0):
    print("Zero")

#else print the number is negative
else:
    print("negative number")
# Out:
# negative number
